# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cust_satisfaction.csv")
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: count, dtype: int64

# %%
df['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    71655
# Personal Travel    32249
# Name: count, dtype: int64

# %%
df["Customer Type"].value_counts()
Female_df = df[df['Gender']=='Female']
Female_df.shape
# Out:
# (52727, 12)

# %%
Female_df['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       42458
# disloyal Customer    10269
# Name: count, dtype: int64

# %%
Female_df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 5       Female     Loyal Customer  Personal Travel       Eco
# 7       Female     Loyal Customer  Business travel  Business
# 8       Female     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103893  Female     Loyal Customer  Business travel  Business
# 103895  Female  disloyal Customer  Business travel       Eco
# 103897  Female     Loyal Customer  Business travel  Business
# 103899  Female  disloyal Customer  Business travel       Eco
# 103902  Female  disloyal Customer  Business travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 2                     satisfied   26             1142                       5
# ...

# %%
female_with4_5 = Female_df[Female_df['Inflight entertainment']>=4]

# %%
female_with4_5['satisfaction'].value_counts()
# Out:
# satisfaction
# satisfied                  17070
# neutral or dissatisfied    10449
# Name: count, dtype: int64

# %%
female_with4_5['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       23340
# disloyal Customer     4179
# Name: count, dtype: int64

# %%
disloyal_female = female_with4_5[female_with4_5['Customer Type']=="disloyal Customer"]

# %%
disloyal_female['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    3209
# satisfied                   970
# Name: count, dtype: int64

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
male = df[df['Gender']=='Male']
male.head()
# Out:
#   Gender      Customer Type   Type of Travel     Class  \
# 0   Male     Loyal Customer  Personal Travel  Eco Plus
# 1   Male  disloyal Customer  Business travel  Business
# 4   Male     Loyal Customer  Business travel  Business
# 6   Male     Loyal Customer  Personal Travel       Eco
# 9   Male  disloyal Customer  Business travel       Eco
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 4                satisfied   61              214                       3
# 6  neutral or dissatisfied   47             1276                       2
# 9  neutral or dissatisfied   20             1061                       2
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# ...

# %%
male['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    28686
# satisfied                  22491
# Name: count, dtype: int64

# %%
male_with_4_5 = male[male['Inflight entertainment'] >=4]
male_with_4_5.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 13   Male     Loyal Customer  Personal Travel       Eco
# 15   Male  disloyal Customer  Business travel       Eco
# 17   Male     Loyal Customer  Business travel  Business
# 19   Male     Loyal Customer  Personal Travel       Eco
#
#                satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0   neutral or dissatisfied   13              460                       5
# 13                satisfied   33              946                       4
# 15  neutral or dissatisfied   13              486                       4
# 17                satisfied   41             2075                       5
# 19  neutral or dissatisfied   38              460                       5
#
#     Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                  4            5                          25
# ...

# %%
male_with_4_5['satisfaction'].value_counts()
# Out:
# satisfaction
# satisfied                  17279
# neutral or dissatisfied     9838
# Name: count, dtype: int64

# %%
male_with_4_5['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       23527
# disloyal Customer     3590
# Name: count, dtype: int64

# %%
disloyal_male=male_with_4_5[male_with_4_5['Customer Type']=='disloyal Customer']
disloyal_male.head(10)
# Out:
#     Gender      Customer Type   Type of Travel     Class  \
# 15    Male  disloyal Customer  Business travel       Eco
# 59    Male  disloyal Customer  Business travel       Eco
# 62    Male  disloyal Customer  Business travel       Eco
# 72    Male  disloyal Customer  Business travel  Business
# 104   Male  disloyal Customer  Business travel  Business
# 144   Male  disloyal Customer  Business travel       Eco
# 157   Male  disloyal Customer  Business travel       Eco
# 166   Male  disloyal Customer  Business travel       Eco
# 239   Male  disloyal Customer  Business travel       Eco
# 249   Male  disloyal Customer  Business travel       Eco
#
#                 satisfaction  Age  Flight Distance  Inflight entertainment  \
# 15   neutral or dissatisfied   13              486                       4
# 59   neutral or dissatisfied   23              446                       4
# 62   neutral or dissatisfied   25              646                       4
# ...

# %%
sns.countplot(df['satisfaction'])
plt.show()

# %%
sns.countplot(df['Customer Type'])
plt.show()

# %%
sns.countplot(df['Class'])
plt.show()

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
male
# Out:
#        Gender      Customer Type   Type of Travel     Class  \
# 0        Male     Loyal Customer  Personal Travel  Eco Plus
# 1        Male  disloyal Customer  Business travel  Business
# 4        Male     Loyal Customer  Business travel  Business
# 6        Male     Loyal Customer  Personal Travel       Eco
# 9        Male  disloyal Customer  Business travel       Eco
# ...       ...                ...              ...       ...
# 103896   Male     Loyal Customer  Business travel       Eco
# 103898   Male     Loyal Customer  Personal Travel       Eco
# 103900   Male     Loyal Customer  Business travel  Business
# 103901   Male  disloyal Customer  Business travel  Business
# 103903   Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
lab = list(Female_df['satisfaction'].value_counts().keys())
lab
# Out:
# ['neutral or dissatisfied', 'satisfied']

# %%
x = list(Female_df['satisfaction'].value_counts().keys())
x
# Out:
# ['neutral or dissatisfied', 'satisfied']

# %%
plt.pie(x , labels = lab,autopct='%.2f%%')
plt.figure(figsize=(8,8))
plt.title('female passenger')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 plt.pie(x , labels = lab,autopct='%.2f%%')
#       2 plt.figure(figsize=(8,8))
#       3 plt.title('female passenger')
#
# File c:\Users\SKTW\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3676, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3653 @_copy_docstring_and_deprecators(Axes.pie)
#    3654 def pie(
#    3655     x: ArrayLike,
#    (...)
#    3674     data=None,
#    3675 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3676     return gca().pie(
#    3677         x,
#    3678         explode=explode,
#    3679         labels=labels,
#    3680         colors=colors,
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
sns.kdeplot(df['Arrival Delay in Minutes'])
# Out:
# <Axes: xlabel='Arrival Delay in Minutes', ylabel='Density'>

# %%
df[df['Arrival Delay in Minutes'].isnull()]
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 213     Female     Loyal Customer  Business travel       Eco
# 1124      Male     Loyal Customer  Personal Travel       Eco
# 1529      Male     Loyal Customer  Business travel  Business
# 2004    Female  disloyal Customer  Business travel  Business
# 2108    Female     Loyal Customer  Personal Travel       Eco
# ...        ...                ...              ...       ...
# 102067    Male     Loyal Customer  Personal Travel  Eco Plus
# 102384    Male     Loyal Customer  Business travel       Eco
# 102552  Female  disloyal Customer  Business travel       Eco
# 102960    Male     Loyal Customer  Business travel       Eco
# 103540  Female     Loyal Customer  Personal Travel       Eco
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 213                   satisfied   38              109                       5
# ...

# %%
satisfied=df[df['satisfaction']=='satisfied']
sns.kdeplot(satisfied['Arrival Delay in Minutes'])
plt.show()

# %%
df.dropna(inplace=True)

# %%
f2 = pd.get_dummies(df , drop_first='if_binary').astype(int)
f2
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 f2 = pd.get_dummies(df , drop_first='if_binary').astype(int)
#       2 f2
#
# File c:\Users\SKTW\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeRegressor
